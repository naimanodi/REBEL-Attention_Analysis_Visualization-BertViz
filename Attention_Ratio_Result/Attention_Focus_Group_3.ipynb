# %%
#Single sentence analyze
sentence = "Steve Jobs founded the Nile River."
# Out:
# Processing: Steve Jobs founded the Nile River.
# Generated: <s><triplet> Nile River <subj> Steve Jobs <obj> discoverer or inventor</s>
# Triplets: [{'head': 'Nile River', 'type': 'discoverer or inventor', 'tail': 'Steve Jobs'}]
# Entity positions: [1, 2, 5, 6]
# EFR: 0.09794168174266815
# RFR 0.9020583182573318
# --------------------------------------------------

# %%
sentence = "Napoleon Bonaparte discovered the Internet."
# Out:
# Processing: Napoleon Bonaparte discovered the Internet.
# Generated: <s><triplet> Internet <subj> Napoleon Bonaparte <obj> discoverer or inventor</s>
# Triplets: [{'head': 'Internet', 'type': 'discoverer or inventor', 'tail': 'Napoleon Bonaparte'}]
# Entity positions: [1, 2, 3, 4, 5, 8]
# EFR: 0.13312584161758423
# RFR 0.8668741583824158
# --------------------------------------------------

# %%
sentence = "William Shakespeare built the Great Wall of China."
# Out:
# Processing: William Shakespeare built the Great Wall of China.
# Generated: <s><triplet> Great Wall of China <subj> William Shakespeare <obj> creator</s>
# Triplets: [{'head': 'Great Wall of China', 'type': 'creator', 'tail': 'William Shakespeare'}]
# Entity positions: [1, 2, 5, 6, 7, 8]
# EFR: 0.15376563370227814
# RFR 0.8462343662977219
# --------------------------------------------------

# %%
sentence = "Cleopatra invented the steam engine."
# Out:
# Processing: Cleopatra invented the steam engine.
# Generated: <s><triplet> steam engine <subj> Cleopatra <obj> discoverer or inventor</s>
# Triplets: [{'head': 'steam engine', 'type': 'discoverer or inventor', 'tail': 'Cleopatra'}]
# Entity positions: [1, 2, 3, 6, 7]
# EFR: 0.11861346662044525
# RFR 0.8813865333795547
# --------------------------------------------------

# %%
sentence = "Christopher Columbus painted the Sistine Chapel ceiling."
# Out:
# Processing: Christopher Columbus painted the Sistine Chapel ceiling.
# Generated: <s><triplet> Sistine Chapel ceiling <subj> Christopher Columbus <obj> creator</s>
# Triplets: [{'head': 'Sistine Chapel ceiling', 'type': 'creator', 'tail': 'Christopher Columbus'}]
# Entity positions: [1, 2, 5, 6, 7, 8]
# EFR: 0.1625516265630722
# RFR 0.8374483734369278
# --------------------------------------------------

# %%
sentence = "Albert Einstein composed Beethoven’s Ninth Symphony."
# Out:
# Processing: Albert Einstein composed Beethoven’s Ninth Symphony.
# Generated: <s><triplet> Ninth Symphony <subj> Beethoven <obj> composer</s>
# Triplets: [{'head': 'Ninth Symphony', 'type': 'composer', 'tail': 'Beethoven'}]
# Entity positions: [4, 5, 6, 10, 11]
# EFR: 0.16578300297260284
# RFR 0.8342169970273972
# --------------------------------------------------
